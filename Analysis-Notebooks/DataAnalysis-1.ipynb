# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
lms_data = pd.read_csv(
    'data_in2/2019-07-18-12-32-33_d43o0sted3.csv'
    )
#my_data = lms_data['State/Province'].astype('category')
# lms_data.mode(axis=0)
test = lms_data.loc[:'City ']
lms_data
# #plt.rcdefaults()
# fig, ax = plt.subplots()
# plt.plot(my_data[])
# plt.ylabel('some numbers')
# plt.show()
# Out:
#                   Full Name     Last Name First Name  \
# 0            Aloisio, Stacy       Aloisio      Stacy
# 1            Aloisio, Stacy       Aloisio      Stacy
# 2            Aloisio, Stacy       Aloisio      Stacy
# 3            Aloisio, Stacy       Aloisio      Stacy
# 4        Andrews, Barbara L       Andrews    Barbara
# 5        Andrews, Barbara L       Andrews    Barbara
# 6        Andrews, Barbara L       Andrews    Barbara
# 7        Andrews, Barbara L       Andrews    Barbara
# 8            Barnett, Kiara       Barnett      Kiara
# 9       Beam, Kendall Wayne          Beam    Kendall
# 10             Bewley, Clay        Bewley       Clay
# 11        Bonserio, Gabriel      Bonserio    Gabriel
# 12        Bonserio, Gabriel      Bonserio    Gabriel
# 13        Bonserio, Gabriel      Bonserio    Gabriel
# 14        Bonserio, Gabriel      Bonserio    Gabriel
# 15              bradt, chad         bradt       chad
# 16            Bradt, Chad T         Bradt       Chad
# ...
